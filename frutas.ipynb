# %%
#!pip install pandas
import pandas as pd
ler_arquivo = pd.read_csv('downloads/frutas_2021.csv', error_bad_lines=False, delimiter=';')
df_exemplo = ler_arquivo
# Changing columns name with index number
tab_2021_excessopeso = df_exemplo.rename(columns={df_exemplo.columns[7]: 'Masculino_2021',df_exemplo.columns[10]: 'Feminino_2021', df_exemplo.columns[4]: 'Total_2021'})
tab_2021_excessopeso = tab_2021_excessopeso[['Indicador', 'Variável','Faixa', 'Total_2021', 'Masculino_2021', 'Feminino_2021']]
ler_arquivo = pd.read_csv('downloads/frutas_2011.csv', error_bad_lines=False, delimiter=';')
df_arquivo2 = ler_arquivo
# Changing columns name with index number
tab_2011_excessopeso = df_arquivo2.rename(columns={df_arquivo2.columns[7]: 'Masculino_2011',df_arquivo2.columns[10]: 'Feminino_2011', df_arquivo2.columns[4]: 'Total_2011'})
tab_2011_excessopeso.loc[tab_2011_excessopeso.Variável == 'Idade (anos)']
excesso_peso_2011 = tab_2011_excessopeso.loc[tab_2011_excessopeso.Variável == 'Idade (anos)']
excesso_peso_2021 = tab_2021_excessopeso.loc[tab_2021_excessopeso.Variável == 'Idade (anos)']
df_novo_x = pd.merge(excesso_peso_2011, excesso_peso_2021, on="Faixa")
df_final = df_novo_x[['Indicador_x','Faixa', 'Total_2011', 'Total_2021','Masculino_2011', 'Masculino_2021', 'Feminino_2011', 'Feminino_2021']]
df_final['Total_2011'] = pd.to_numeric(df_final['Total_2011'].str.replace(',', '.').astype(float), downcast='float')
df_final['Total_2021'] = pd.to_numeric(df_final['Total_2021'].str.replace(',', '.').astype(float), downcast='float')
df_final['Masculino_2021'] = pd.to_numeric(df_final['Masculino_2021'].str.replace(',', '.').astype(float), downcast='float')
df_final['Masculino_2011'] = pd.to_numeric(df_final['Masculino_2011'].str.replace(',', '.').astype(float), downcast='float')
df_final['Feminino_2021'] = pd.to_numeric(df_final['Feminino_2021'].str.replace(',', '.').astype(float), downcast='float')
df_final['Feminino_2011'] = pd.to_numeric(df_final['Feminino_2011'].str.replace(',', '.').astype(float), downcast='float')
df_final['Variacao_fem'] = df_final['Feminino_2021'] - df_final['Feminino_2011']
df_final['Variacao_masc'] = df_final['Masculino_2021'] - df_final['Masculino_2011']
df_final['Variacao_total'] = df_final['Total_2021'] - df_final['Total_2011']
df_final.round(2)
# Out:
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3694/1859585071.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ler_arquivo = pd.read_csv('downloads/frutas_2021.csv', error_bad_lines=False, delimiter=';')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3694/1859585071.py:8: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ler_arquivo = pd.read_csv('downloads/frutas_2011.csv', error_bad_lines=False, delimiter=';')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3694/1859585071.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Total_2011'] = pd.to_numeric(df_final['Total_2011'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3694/1859585071.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Total_2021'] = pd.to_numeric(df_final['Total_2021'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3694/1859585071.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Masculino_2021'] = pd.to_numeric(df_final['Masculino_2021'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3694/1859585071.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Masculino_2011'] = pd.to_numeric(df_final['Masculino_2011'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3694/1859585071.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Feminino_2021'] = pd.to_numeric(df_final['Feminino_2021'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3694/1859585071.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Feminino_2011'] = pd.to_numeric(df_final['Feminino_2011'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3694/1859585071.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Variacao_fem'] = df_final['Feminino_2021'] - df_final['Feminino_2011']
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3694/1859585071.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Variacao_masc'] = df_final['Masculino_2021'] - df_final['Masculino_2011']
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3694/1859585071.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Variacao_total'] = df_final['Total_2021'] - df_final['Total_2011']
#                                          Indicador_x      Faixa  Total_2011  \
# 0  Percentual de adultos (≥ 18 anos) que consomem...    18 a 24   24.650000
# 1  Percentual de adultos (≥ 18 anos) que consomem...    25 a 34   28.350000
# 2  Percentual de adultos (≥ 18 anos) que consomem...    35 a 44   32.939999
# 3  Percentual de adultos (≥ 18 anos) que consomem...    45 a 54   36.520000
# 4  Percentual de adultos (≥ 18 anos) que consomem...    55 a 64   42.910000
# 5  Percentual de adultos (≥ 18 anos) que consomem...  65 e mais   48.759998
#
#    Total_2021  Masculino_2011  Masculino_2021  Feminino_2011  Feminino_2021  \
# 0   26.309999       22.580000       24.410000      26.790001      28.430000
# 1   31.139999       23.480000       22.490000      32.860001      38.669998
# 2   31.030001       26.900000       22.139999      37.939999      38.080002
# 3   36.189999       27.080000       29.700001      44.279999      41.980000
# 4   40.330002       34.130001       28.540001      49.560001      49.349998
# 5   44.709999       44.700001       36.189999      51.419998      50.630001
#
#    Variacao_fem  Variacao_masc  Variacao_total
# 0          1.64           1.83            1.66
# 1          5.81          -0.99            2.79
# 2          0.14          -4.76           -1.91
# 3         -2.30           2.62           -0.33
# 4         -0.21          -5.59           -2.58
# 5         -0.79          -8.51           -4.05

# %%
df_final
# Out:
#                                          Indicador_x      Faixa  Total_2011  \
# 0  Percentual de adultos (≥ 18 anos) que consomem...    18 a 24   24.650000
# 1  Percentual de adultos (≥ 18 anos) que consomem...    25 a 34   28.350000
# 2  Percentual de adultos (≥ 18 anos) que consomem...    35 a 44   32.939999
# 3  Percentual de adultos (≥ 18 anos) que consomem...    45 a 54   36.520000
# 4  Percentual de adultos (≥ 18 anos) que consomem...    55 a 64   42.910000
# 5  Percentual de adultos (≥ 18 anos) que consomem...  65 e mais   48.759998
#
#    Total_2021  Masculino_2011  Masculino_2021  Feminino_2011  Feminino_2021  \
# 0   26.309999       22.580000       24.410000      26.790001      28.430000
# 1   31.139999       23.480000       22.490000      32.860001      38.669998
# 2   31.030001       26.900000       22.139999      37.939999      38.080002
# 3   36.189999       27.080000       29.700001      44.279999      41.980000
# 4   40.330002       34.130001       28.540001      49.560001      49.349998
# 5   44.709999       44.700001       36.189999      51.419998      50.630001
#
#    Variacao_fem  Variacao_masc  Variacao_total
# 0      1.639999       1.830000        1.660000
# 1      5.809998      -0.990000        2.789999
# 2      0.140003      -4.760000       -1.909998
# 3     -2.299999       2.620001       -0.330002
# 4     -0.210003      -5.590000       -2.579998
# 5     -0.789997      -8.510002       -4.049999

# %%
# converting to CSV file
df_final.to_csv("frutas.csv")
