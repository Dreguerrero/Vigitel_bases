# %%
#!pip install pandas
import pandas as pd
ler_arquivo = pd.read_csv('downloads/fumantes_2021.csv', error_bad_lines=False, delimiter=';')
df_exemplo = ler_arquivo
# Changing columns name with index number
tab_2021_excessopeso = df_exemplo.rename(columns={df_exemplo.columns[7]: 'Masculino_2021',df_exemplo.columns[10]: 'Feminino_2021', df_exemplo.columns[4]: 'Total_2021'})
tab_2021_excessopeso = tab_2021_excessopeso[['Indicador', 'Variável','Faixa', 'Total_2021', 'Masculino_2021', 'Feminino_2021']]
ler_arquivo = pd.read_csv('downloads/fumantes_2011.csv', error_bad_lines=False, delimiter=';')
df_arquivo2 = ler_arquivo
# Changing columns name with index number
tab_2011_excessopeso = df_arquivo2.rename(columns={df_arquivo2.columns[7]: 'Masculino_2011',df_arquivo2.columns[10]: 'Feminino_2011', df_arquivo2.columns[4]: 'Total_2011'})
tab_2011_excessopeso.loc[tab_2011_excessopeso.Variável == 'Idade (anos)']
excesso_peso_2011 = tab_2011_excessopeso.loc[tab_2011_excessopeso.Variável == 'Idade (anos)']
excesso_peso_2021 = tab_2021_excessopeso.loc[tab_2021_excessopeso.Variável == 'Idade (anos)']
df_novo_x = pd.merge(excesso_peso_2011, excesso_peso_2021, on="Faixa")
df_final = df_novo_x[['Indicador_x','Faixa', 'Total_2011', 'Total_2021','Masculino_2011', 'Masculino_2021', 'Feminino_2011', 'Feminino_2021']]
df_final['Total_2011'] = pd.to_numeric(df_final['Total_2011'].str.replace(',', '.').astype(float), downcast='float')
df_final['Total_2021'] = pd.to_numeric(df_final['Total_2021'].str.replace(',', '.').astype(float), downcast='float')
df_final['Masculino_2021'] = pd.to_numeric(df_final['Masculino_2021'].str.replace(',', '.').astype(float), downcast='float')
df_final['Masculino_2011'] = pd.to_numeric(df_final['Masculino_2011'].str.replace(',', '.').astype(float), downcast='float')
df_final['Feminino_2021'] = pd.to_numeric(df_final['Feminino_2021'].str.replace(',', '.').astype(float), downcast='float')
df_final['Feminino_2011'] = pd.to_numeric(df_final['Feminino_2011'].str.replace(',', '.').astype(float), downcast='float')
df_final['Variacao_fem'] = df_final['Feminino_2021'] - df_final['Feminino_2011']
df_final['Variacao_masc'] = df_final['Masculino_2021'] - df_final['Masculino_2011']
df_final['Variacao_total'] = df_final['Total_2021'] - df_final['Total_2011']
df_final.round(2)
# Out:
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3467/566950922.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ler_arquivo = pd.read_csv('downloads/fumantes_2021.csv', error_bad_lines=False, delimiter=';')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3467/566950922.py:8: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ler_arquivo = pd.read_csv('downloads/fumantes_2011.csv', error_bad_lines=False, delimiter=';')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3467/566950922.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Total_2011'] = pd.to_numeric(df_final['Total_2011'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3467/566950922.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Total_2021'] = pd.to_numeric(df_final['Total_2021'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3467/566950922.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Masculino_2021'] = pd.to_numeric(df_final['Masculino_2021'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3467/566950922.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Masculino_2011'] = pd.to_numeric(df_final['Masculino_2011'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3467/566950922.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Feminino_2021'] = pd.to_numeric(df_final['Feminino_2021'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3467/566950922.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Feminino_2011'] = pd.to_numeric(df_final['Feminino_2011'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3467/566950922.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Variacao_fem'] = df_final['Feminino_2021'] - df_final['Feminino_2011']
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3467/566950922.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Variacao_masc'] = df_final['Masculino_2021'] - df_final['Masculino_2011']
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3467/566950922.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Variacao_total'] = df_final['Total_2021'] - df_final['Total_2011']
#                                   Indicador_x      Faixa  Total_2011  \
# 0  Percentual de adultos (≥ 18 anos) fumantes    18 a 24    8.760000
# 1  Percentual de adultos (≥ 18 anos) fumantes    25 a 34   13.160000
# 2  Percentual de adultos (≥ 18 anos) fumantes    35 a 44   13.940000
# 3  Percentual de adultos (≥ 18 anos) fumantes    45 a 54   18.629999
# 4  Percentual de adultos (≥ 18 anos) fumantes    55 a 64   15.860000
# 5  Percentual de adultos (≥ 18 anos) fumantes  65 e mais    9.020000
#
#    Total_2021  Masculino_2011  Masculino_2021  Feminino_2011  Feminino_2021  \
# 0        6.38       11.180000            7.21       6.260000           5.45
# 1        7.27       18.080000           11.85       8.590000           3.27
# 2       11.63       15.960000           17.66      12.260000           6.87
# 3       10.13       20.389999           11.63      17.190001           8.78
# 4       11.54       19.290001           13.11      13.250000          10.34
# 5        7.43       13.960000            7.30       5.780000           7.52
#
#    Variacao_fem  Variacao_masc  Variacao_total
# 0         -0.81          -3.97           -2.38
# 1         -5.32          -6.23           -5.89
# 2         -5.39           1.70           -2.31
# 3         -8.41          -8.76           -8.50
# 4         -2.91          -6.18           -4.32
# 5          1.74          -6.66           -1.59

# %%
# converting to CSV file
df_final.to_csv("fumantes.csv")
