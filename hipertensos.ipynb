# %%
ç
# Out:
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3537/931264738.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ler_arquivo = pd.read_csv('downloads/hipert_2021.csv', error_bad_lines=False, delimiter=';')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3537/931264738.py:8: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ler_arquivo = pd.read_csv('downloads/hipert_2011.csv', error_bad_lines=False, delimiter=';')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3537/931264738.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_final
# Out:
#                                          Indicador_x      Faixa  Total_2011  \
# 0  Percentual de adultos (≥ 18 anos) que referira...    18 a 24    3.980000
# 1  Percentual de adultos (≥ 18 anos) que referira...    25 a 34    9.360000
# 2  Percentual de adultos (≥ 18 anos) que referira...    35 a 44   19.629999
# 3  Percentual de adultos (≥ 18 anos) que referira...    45 a 54   34.419998
# 4  Percentual de adultos (≥ 18 anos) que referira...    55 a 64   49.959999
# 5  Percentual de adultos (≥ 18 anos) que referira...  65 e mais   59.669998
#
#    Total_2021  Masculino_2011  Masculino_2021  Feminino_2011  Feminino_2021  \
# 0    3.760000        4.100000        3.090000       3.850000       4.520000
# 1   12.240000        9.200000       13.930000       9.510000      10.770000
# 2   18.590000       18.879999       19.850000      20.250000      17.600000
# 3   30.920000       31.490000       32.779999      36.830002      29.260000
# ...

# %%
# converting to CSV file
df_final.to_csv("hipert.csv")
