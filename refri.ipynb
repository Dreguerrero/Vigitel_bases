# %%
#!pip install pandas
import pandas as pd
ler_arquivo = pd.read_csv('downloads/refri_2021.csv', error_bad_lines=False, delimiter=';')
df_exemplo = ler_arquivo
# Changing columns name with index number
tab_2021_excessopeso = df_exemplo.rename(columns={df_exemplo.columns[7]: 'Masculino_2021',df_exemplo.columns[10]: 'Feminino_2021', df_exemplo.columns[4]: 'Total_2021'})
tab_2021_excessopeso = tab_2021_excessopeso[['Indicador', 'Variável','Faixa', 'Total_2021', 'Masculino_2021', 'Feminino_2021']]
ler_arquivo = pd.read_csv('downloads/refri_2011.csv', error_bad_lines=False, delimiter=';')
df_arquivo2 = ler_arquivo
# Changing columns name with index number
tab_2011_excessopeso = df_arquivo2.rename(columns={df_arquivo2.columns[7]: 'Masculino_2011',df_arquivo2.columns[10]: 'Feminino_2011', df_arquivo2.columns[4]: 'Total_2011'})
tab_2011_excessopeso.loc[tab_2011_excessopeso.Variável == 'Idade (anos)']
excesso_peso_2011 = tab_2011_excessopeso.loc[tab_2011_excessopeso.Variável == 'Idade (anos)']
excesso_peso_2021 = tab_2021_excessopeso.loc[tab_2021_excessopeso.Variável == 'Idade (anos)']
df_novo_x = pd.merge(excesso_peso_2011, excesso_peso_2021, on="Faixa")
df_final = df_novo_x[['Indicador_x','Faixa', 'Total_2011', 'Total_2021','Masculino_2011', 'Masculino_2021', 'Feminino_2011', 'Feminino_2021']]
df_final['Total_2011'] = pd.to_numeric(df_final['Total_2011'].str.replace(',', '.').astype(float), downcast='float')
df_final['Total_2021'] = pd.to_numeric(df_final['Total_2021'].str.replace(',', '.').astype(float), downcast='float')
df_final['Masculino_2021'] = pd.to_numeric(df_final['Masculino_2021'].str.replace(',', '.').astype(float), downcast='float')
df_final['Masculino_2011'] = pd.to_numeric(df_final['Masculino_2011'].str.replace(',', '.').astype(float), downcast='float')
df_final['Feminino_2021'] = pd.to_numeric(df_final['Feminino_2021'].str.replace(',', '.').astype(float), downcast='float')
df_final['Feminino_2011'] = pd.to_numeric(df_final['Feminino_2011'].str.replace(',', '.').astype(float), downcast='float')
df_final['Variacao_fem'] = df_final['Feminino_2021'] - df_final['Feminino_2011']
df_final['Variacao_masc'] = df_final['Masculino_2021'] - df_final['Masculino_2011']
df_final['Variacao_total'] = df_final['Total_2021'] - df_final['Total_2011']
df_final.round(2)
# Out:
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3620/3554875800.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ler_arquivo = pd.read_csv('downloads/refri_2021.csv', error_bad_lines=False, delimiter=';')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3620/3554875800.py:8: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ler_arquivo = pd.read_csv('downloads/refri_2011.csv', error_bad_lines=False, delimiter=';')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3620/3554875800.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Total_2011'] = pd.to_numeric(df_final['Total_2011'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3620/3554875800.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Total_2021'] = pd.to_numeric(df_final['Total_2021'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3620/3554875800.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Masculino_2021'] = pd.to_numeric(df_final['Masculino_2021'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3620/3554875800.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Masculino_2011'] = pd.to_numeric(df_final['Masculino_2011'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3620/3554875800.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Feminino_2021'] = pd.to_numeric(df_final['Feminino_2021'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3620/3554875800.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Feminino_2011'] = pd.to_numeric(df_final['Feminino_2011'].str.replace(',', '.').astype(float), downcast='float')
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3620/3554875800.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Variacao_fem'] = df_final['Feminino_2021'] - df_final['Feminino_2011']
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3620/3554875800.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Variacao_masc'] = df_final['Masculino_2021'] - df_final['Masculino_2011']
# /var/folders/kq/pf42y0p14nz9g39mh_c2zh0w0000gn/T/ipykernel_3620/3554875800.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Variacao_total'] = df_final['Total_2021'] - df_final['Total_2011']
#                                          Indicador_x      Faixa  Total_2011  \
# 0  Percentual de adultos (≥ 18 anos) que consomem...    18 a 24   39.560001
# 1  Percentual de adultos (≥ 18 anos) que consomem...    25 a 34   32.759998
# 2  Percentual de adultos (≥ 18 anos) que consomem...    35 a 44   26.430000
# 3  Percentual de adultos (≥ 18 anos) que consomem...    45 a 54   22.760000
# 4  Percentual de adultos (≥ 18 anos) que consomem...    55 a 64   18.549999
# 5  Percentual de adultos (≥ 18 anos) que consomem...  65 e mais   14.080000
#
#    Total_2021  Masculino_2011  Masculino_2021  Feminino_2011  Feminino_2021  \
# 0       19.66       42.380001       21.040001      36.650002          18.10
# 1       18.32       37.150002       24.889999      28.680000          12.60
# 2       13.14       31.330000       15.390000      22.370001          11.35
# 3       11.89       27.700001       13.460000      18.700001          10.50
# 4        9.14       21.450001       10.560000      16.350000           8.06
# 5        8.74       17.030001       11.160000      12.140000           7.06
#
#    Variacao_fem  Variacao_masc  Variacao_total
# 0    -18.549999         -21.34          -19.90
# 1    -16.080000         -12.26          -14.44
# 2    -11.020000         -15.94          -13.29
# 3     -8.200000         -14.24          -10.87
# 4     -8.290000         -10.89           -9.41
# 5     -5.080000          -5.87           -5.34

# %%
df_final
# Out:
#                                          Indicador_x      Faixa  Total_2011  \
# 0  Percentual de adultos (≥ 18 anos) que consomem...    18 a 24   39.560001
# 1  Percentual de adultos (≥ 18 anos) que consomem...    25 a 34   32.759998
# 2  Percentual de adultos (≥ 18 anos) que consomem...    35 a 44   26.430000
# 3  Percentual de adultos (≥ 18 anos) que consomem...    45 a 54   22.760000
# 4  Percentual de adultos (≥ 18 anos) que consomem...    55 a 64   18.549999
# 5  Percentual de adultos (≥ 18 anos) que consomem...  65 e mais   14.080000
#
#    Total_2021  Masculino_2011  Masculino_2021  Feminino_2011  Feminino_2021  \
# 0       19.66       42.380001       21.040001      36.650002          18.10
# 1       18.32       37.150002       24.889999      28.680000          12.60
# 2       13.14       31.330000       15.390000      22.370001          11.35
# 3       11.89       27.700001       13.460000      18.700001          10.50
# 4        9.14       21.450001       10.560000      16.350000           8.06
# 5        8.74       17.030001       11.160000      12.140000           7.06
#
#    Variacao_fem  Variacao_masc  Variacao_total
# 0    -18.550001     -21.340000      -19.900002
# 1    -16.080000     -12.260002      -14.439999
# 2    -11.020000     -15.940000      -13.290000
# 3     -8.200001     -14.240001      -10.870000
# 4     -8.290000     -10.890000       -9.409999
# 5     -5.080000      -5.870001       -5.340000

# %%
# converting to CSV file
df_final.to_csv("refri.csv")
